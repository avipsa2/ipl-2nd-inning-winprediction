# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns

# %%
match=pd.read_csv(r"C:\Users\Asus\Downloads\IPL+match+predictor-+Code+Files\Code Files\matches.csv")
delivery=pd.read_csv(r"C:\Users\Asus\Downloads\IPL+match+predictor-+Code+Files\Code Files\deliveries.csv")
delivery.head()
# Out:
#    match_id  inning         batting_team                 bowling_team  over  \
# 0         1       1  Sunrisers Hyderabad  Royal Challengers Bangalore     1
# 1         1       1  Sunrisers Hyderabad  Royal Challengers Bangalore     1
# 2         1       1  Sunrisers Hyderabad  Royal Challengers Bangalore     1
# 3         1       1  Sunrisers Hyderabad  Royal Challengers Bangalore     1
# 4         1       1  Sunrisers Hyderabad  Royal Challengers Bangalore     1
#
#    ball    batsman non_striker    bowler  is_super_over  ...  bye_runs  \
# 0     1  DA Warner    S Dhawan  TS Mills              0  ...         0
# 1     2  DA Warner    S Dhawan  TS Mills              0  ...         0
# 2     3  DA Warner    S Dhawan  TS Mills              0  ...         0
# 3     4  DA Warner    S Dhawan  TS Mills              0  ...         0
# 4     5  DA Warner    S Dhawan  TS Mills              0  ...         0
#
#    legbye_runs  noball_runs  penalty_runs  batsman_runs  extra_runs  \
# ...

# %%
match.head()
# Out:
#    id    Season       city        date                        team1  \
# 0   1  IPL-2017  Hyderabad  05-04-2017          Sunrisers Hyderabad
# 1   2  IPL-2017       Pune  06-04-2017               Mumbai Indians
# 2   3  IPL-2017     Rajkot  07-04-2017                Gujarat Lions
# 3   4  IPL-2017     Indore  08-04-2017       Rising Pune Supergiant
# 4   5  IPL-2017  Bangalore  08-04-2017  Royal Challengers Bangalore
#
#                          team2                  toss_winner toss_decision  \
# 0  Royal Challengers Bangalore  Royal Challengers Bangalore         field
# 1       Rising Pune Supergiant       Rising Pune Supergiant         field
# 2        Kolkata Knight Riders        Kolkata Knight Riders         field
# 3              Kings XI Punjab              Kings XI Punjab         field
# 4             Delhi Daredevils  Royal Challengers Bangalore           bat
#
#    result  dl_applied                       winner  win_by_runs  \
# ...

# %%
totalrun=delivery.groupby(['match_id','inning']).sum()['total_runs'].reset_index()
totalrun
# Out:
#       match_id  inning  total_runs
# 0            1       1         207
# 1            1       2         172
# 2            2       1         184
# 3            2       2         187
# 4            3       1         183
# ...        ...     ...         ...
# 1523     11413       2         170
# 1524     11414       1         155
# 1525     11414       2         162
# 1526     11415       1         152
# 1527     11415       2         157
#
# [1528 rows x 3 columns]

# %%
match.shape
# Out:
# (756, 18)

# %%
totalrun=totalrun[totalrun['inning']==1]
totalrun['total_runs']=totalrun['total_runs'].apply(lambda x:x+1)
# Out:
# C:\Users\Asus\AppData\Local\Temp\ipykernel_24976\3838622156.py:2: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   totalrun['total_runs']=totalrun['total_runs'].apply(lambda x:x+1)

# %%
match_df=match.merge(totalrun[['match_id','total_runs']],left_on='id',right_on='match_id')

# %%
match_df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 756 entries, 0 to 755
# Data columns (total 20 columns):
#  #   Column           Non-Null Count  Dtype
# ---  ------           --------------  -----
#  0   id               756 non-null    int64
#  1   Season           756 non-null    object
#  2   city             749 non-null    object
#  3   date             756 non-null    object
#  4   team1            756 non-null    object
#  5   team2            756 non-null    object
#  6   toss_winner      756 non-null    object
#  7   toss_decision    756 non-null    object
#  8   result           756 non-null    object
#  9   dl_applied       756 non-null    int64
#  10  winner           752 non-null    object
#  11  win_by_runs      756 non-null    int64
#  12  win_by_wickets   756 non-null    int64
#  13  player_of_match  752 non-null    object
#  14  venue            756 non-null    object
#  15  umpire1          754 non-null    object
#  16  umpire2          754 non-null    object
# ...

# %%
match_df['team1'].unique()
# Out:
# array(['Sunrisers Hyderabad', 'Mumbai Indians', 'Gujarat Lions',
#        'Rising Pune Supergiant', 'Royal Challengers Bangalore',
#        'Kolkata Knight Riders', 'Delhi Daredevils', 'Kings XI Punjab',
#        'Chennai Super Kings', 'Rajasthan Royals', 'Deccan Chargers',
#        'Kochi Tuskers Kerala', 'Pune Warriors', 'Rising Pune Supergiants',
#        'Delhi Capitals'], dtype=object)

# %%
team=['Sunrisers Hyderabad', 'Mumbai Indians','Royal Challengers Bangalore',
       'Kolkata Knight Riders', 'Delhi Daredevils', 'Kings XI Punjab',
       'Chennai Super Kings', 'Rajasthan Royals','Delhi Capitals']

# %%
match_df['team1']=match_df['team1'].str.replace('Delhi Daredevils','Delhi Capitals')

# %%
match_df['team2']=match_df['team2'].str.replace('Delhi Daredevils','Delhi Capitals')

# %%
match_df['team1']=match_df['team1'].str.replace('Deccan Chargers','Sunrisers Hyderabad')
match_df['team2']=match_df['team2'].str.replace('Deccan Chargers','Sunrisers Hyderabad')

# %%
match_df=match_df[match_df['team1'].isin(team)]
match_df=match_df[match_df['team2'].isin(team)]

# %%
match_df.shape
# Out:
# (641, 20)

# %%
match_df[match_df['dl_applied']==1]
# Out:
#        id    Season           city        date                        team1  \
# 56     57  IPL-2017      Bangalore  17-05-2017          Sunrisers Hyderabad
# 99    100  IPL-2008          Delhi  17-05-2008               Delhi Capitals
# 102   103  IPL-2008        Kolkata  18-05-2008        Kolkata Knight Riders
# 119   120  IPL-2009      Cape Town  19-04-2009              Kings XI Punjab
# 122   123  IPL-2009         Durban  21-04-2009              Kings XI Punjab
# 148   149  IPL-2009      Centurion  07-05-2009          Chennai Super Kings
# 280   281  IPL-2011        Kolkata  07-05-2011          Chennai Super Kings
# 290   291  IPL-2011      Bangalore  14-05-2011        Kolkata Knight Riders
# 488   489  IPL-2014          Delhi  10-05-2014               Delhi Capitals
# 536   537  IPL-2015  Visakhapatnam  22-04-2015          Sunrisers Hyderabad
# 567   568  IPL-2015      Hyderabad  15-05-2015          Sunrisers Hyderabad
# ...

# %%
match_df=match_df[match_df['dl_applied']==0]

# %%
match_df.shape
# Out:
# (626, 20)

# %%
match_df=match_df[['match_id','total_runs','city','winner']]

# %%
delivery_df=match_df.merge(delivery,on='match_id')

# %%
delivery_df
# Out:
#         match_id  total_runs_x       city               winner  inning  \
# 0              1           208  Hyderabad  Sunrisers Hyderabad       1
# 1              1           208  Hyderabad  Sunrisers Hyderabad       1
# 2              1           208  Hyderabad  Sunrisers Hyderabad       1
# 3              1           208  Hyderabad  Sunrisers Hyderabad       1
# 4              1           208  Hyderabad  Sunrisers Hyderabad       1
# ...          ...           ...        ...                  ...     ...
# 149573     11415           153  Hyderabad       Mumbai Indians       2
# 149574     11415           153  Hyderabad       Mumbai Indians       2
# 149575     11415           153  Hyderabad       Mumbai Indians       2
# 149576     11415           153  Hyderabad       Mumbai Indians       2
# 149577     11415           153  Hyderabad       Mumbai Indians       2
#
#                batting_team                 bowling_team  over  ball  \
# ...

# %%
delivery_df=delivery_df[delivery_df['inning']==2]

# %%
delivery_df
# Out:
#         match_id  total_runs_x       city               winner  inning  \
# 125            1           208  Hyderabad  Sunrisers Hyderabad       2
# 126            1           208  Hyderabad  Sunrisers Hyderabad       2
# 127            1           208  Hyderabad  Sunrisers Hyderabad       2
# 128            1           208  Hyderabad  Sunrisers Hyderabad       2
# 129            1           208  Hyderabad  Sunrisers Hyderabad       2
# ...          ...           ...        ...                  ...     ...
# 149573     11415           153  Hyderabad       Mumbai Indians       2
# 149574     11415           153  Hyderabad       Mumbai Indians       2
# 149575     11415           153  Hyderabad       Mumbai Indians       2
# 149576     11415           153  Hyderabad       Mumbai Indians       2
# 149577     11415           153  Hyderabad       Mumbai Indians       2
#
#                        batting_team         bowling_team  over  ball  \
# ...

# %%
delivery_df['current_score'] = delivery_df.groupby('match_id')['total_runs_y'].cumsum()
# Out:
# C:\Users\Asus\AppData\Local\Temp\ipykernel_24976\2372950602.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   delivery_df['current_score'] = delivery_df.groupby('match_id')['total_runs_y'].cumsum()

# %%
delivery_df
# Out:
#         match_id  total_runs_x       city               winner  inning  \
# 125            1           208  Hyderabad  Sunrisers Hyderabad       2
# 126            1           208  Hyderabad  Sunrisers Hyderabad       2
# 127            1           208  Hyderabad  Sunrisers Hyderabad       2
# 128            1           208  Hyderabad  Sunrisers Hyderabad       2
# 129            1           208  Hyderabad  Sunrisers Hyderabad       2
# ...          ...           ...        ...                  ...     ...
# 149573     11415           153  Hyderabad       Mumbai Indians       2
# 149574     11415           153  Hyderabad       Mumbai Indians       2
# 149575     11415           153  Hyderabad       Mumbai Indians       2
# 149576     11415           153  Hyderabad       Mumbai Indians       2
# 149577     11415           153  Hyderabad       Mumbai Indians       2
#
#                        batting_team         bowling_team  over  ball  \
# ...

# %%
delivery_df['runs_left']=delivery_df['total_runs_x']-delivery_df['current_score']
# Out:
# C:\Users\Asus\AppData\Local\Temp\ipykernel_24976\3239114318.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   delivery_df['runs_left']=delivery_df['total_runs_x']-delivery_df['current_score']

# %%
delivery_df['balls_left']=126-(delivery_df['over']*6+delivery_df['ball'])
# Out:
# C:\Users\Asus\AppData\Local\Temp\ipykernel_24976\2918661865.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   delivery_df['balls_left']=126-(delivery_df['over']*6+delivery_df['ball'])

# %%
delivery_df['player_dismissed']=delivery_df['player_dismissed'].fillna("0")
# Out:
# C:\Users\Asus\AppData\Local\Temp\ipykernel_24976\2323000106.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   delivery_df['player_dismissed']=delivery_df['player_dismissed'].fillna("0")

# %%
delivery_df['player_dismissed']=delivery_df['player_dismissed'].apply(lambda x:x if x=="0" else "1")
# Out:
# C:\Users\Asus\AppData\Local\Temp\ipykernel_24976\136881925.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   delivery_df['player_dismissed']=delivery_df['player_dismissed'].apply(lambda x:x if x=="0" else "1")

# %%
delivery_df['player_dismissed']=delivery_df['player_dismissed'].astype('int')
delivery_df['player_dismissed'].unique()
# Out:
# C:\Users\Asus\AppData\Local\Temp\ipykernel_24976\708337877.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   delivery_df['player_dismissed']=delivery_df['player_dismissed'].astype('int')
# array([0, 1])

# %%
delivery_df['current_runrate']=delivery_df['current_score']*6/(120-delivery_df['balls_left'])
# Out:
# C:\Users\Asus\AppData\Local\Temp\ipykernel_24976\2213636366.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   delivery_df['current_runrate']=delivery_df['current_score']*6/(120-delivery_df['balls_left'])

# %%
delivery_df['req_runrate']=(delivery_df['runs_left']*6)/(delivery_df['balls_left'])
# Out:
# C:\Users\Asus\AppData\Local\Temp\ipykernel_24976\3134058931.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   delivery_df['req_runrate']=(delivery_df['runs_left']*6)/(delivery_df['balls_left'])

# %%
wickets=delivery_df.groupby('match_id')['player_dismissed'].cumsum().values

# %%
delivery_df['wickets_left']=10-wickets
# Out:
# C:\Users\Asus\AppData\Local\Temp\ipykernel_24976\2791015334.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   delivery_df['wickets_left']=10-wickets

# %%
delivery_df.head()
# Out:
#      match_id  total_runs_x       city               winner  inning  \
# 125         1           208  Hyderabad  Sunrisers Hyderabad       2
# 126         1           208  Hyderabad  Sunrisers Hyderabad       2
# 127         1           208  Hyderabad  Sunrisers Hyderabad       2
# 128         1           208  Hyderabad  Sunrisers Hyderabad       2
# 129         1           208  Hyderabad  Sunrisers Hyderabad       2
#
#                     batting_team         bowling_team  over  ball  \
# 125  Royal Challengers Bangalore  Sunrisers Hyderabad     1     1
# 126  Royal Challengers Bangalore  Sunrisers Hyderabad     1     2
# 127  Royal Challengers Bangalore  Sunrisers Hyderabad     1     3
# 128  Royal Challengers Bangalore  Sunrisers Hyderabad     1     4
# 129  Royal Challengers Bangalore  Sunrisers Hyderabad     1     5
#
#            batsman  ... total_runs_y player_dismissed  dismissal_kind  \
# 125       CH Gayle  ...            1                0             NaN
# ...

# %%
def resultfun(x):
    return 1 if x['batting_team']==x['winner'] else 0

# %%
delivery_df['result']=delivery_df.apply(resultfun,axis=1)
# Out:
# C:\Users\Asus\AppData\Local\Temp\ipykernel_24976\1393997026.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   delivery_df['result']=delivery_df.apply(resultfun,axis=1)

# %%
delivery_df.head(10)
# Out:
#      match_id  total_runs_x       city               winner  inning  \
# 125         1           208  Hyderabad  Sunrisers Hyderabad       2
# 126         1           208  Hyderabad  Sunrisers Hyderabad       2
# 127         1           208  Hyderabad  Sunrisers Hyderabad       2
# 128         1           208  Hyderabad  Sunrisers Hyderabad       2
# 129         1           208  Hyderabad  Sunrisers Hyderabad       2
# 130         1           208  Hyderabad  Sunrisers Hyderabad       2
# 131         1           208  Hyderabad  Sunrisers Hyderabad       2
# 132         1           208  Hyderabad  Sunrisers Hyderabad       2
# 133         1           208  Hyderabad  Sunrisers Hyderabad       2
# 134         1           208  Hyderabad  Sunrisers Hyderabad       2
#
#                     batting_team         bowling_team  over  ball  \
# 125  Royal Challengers Bangalore  Sunrisers Hyderabad     1     1
# 126  Royal Challengers Bangalore  Sunrisers Hyderabad     1     2
# ...

# %%
delivery_df.columns
# Out:
# Index(['match_id', 'total_runs_x', 'city', 'winner', 'inning', 'batting_team',
#        'bowling_team', 'over', 'ball', 'batsman', 'non_striker', 'bowler',
#        'is_super_over', 'wide_runs', 'bye_runs', 'legbye_runs', 'noball_runs',
#        'penalty_runs', 'batsman_runs', 'extra_runs', 'total_runs_y',
#        'player_dismissed', 'dismissal_kind', 'fielder', 'current_score',
#        'runs_left', 'balls_left', 'current_runrate', 'req_runrate',
#        'wickets_left', 'result'],
#       dtype='object')

# %%
final_df=delivery_df[['batting_team','bowling_team','city','balls_left','wickets_left','total_runs_x','current_runrate','req_runrate','result']]

# %%
final_df
# Out:
#                        batting_team         bowling_team       city  \
# 125     Royal Challengers Bangalore  Sunrisers Hyderabad  Hyderabad
# 126     Royal Challengers Bangalore  Sunrisers Hyderabad  Hyderabad
# 127     Royal Challengers Bangalore  Sunrisers Hyderabad  Hyderabad
# 128     Royal Challengers Bangalore  Sunrisers Hyderabad  Hyderabad
# 129     Royal Challengers Bangalore  Sunrisers Hyderabad  Hyderabad
# ...                             ...                  ...        ...
# 149573          Chennai Super Kings       Mumbai Indians  Hyderabad
# 149574          Chennai Super Kings       Mumbai Indians  Hyderabad
# 149575          Chennai Super Kings       Mumbai Indians  Hyderabad
# 149576          Chennai Super Kings       Mumbai Indians  Hyderabad
# 149577          Chennai Super Kings       Mumbai Indians  Hyderabad
#
#         balls_left  wickets_left  total_runs_x  current_runrate  req_runrate  \
# ...

# %%
final_df.isna().sum()
# Out:
# batting_team         0
# bowling_team         0
# city               832
# balls_left           0
# wickets_left         0
# total_runs_x         0
# current_runrate      0
# req_runrate          5
# result               0
# dtype: int64

# %%
final_df=final_df.fillna(0)

# %%
final_df=final_df[final_df['balls_left']!=0]

# %%
categorical_cols = ['batting_team', 'bowling_team', 'city']
for col in categorical_cols:
    final_df[col] = final_df[col].astype(str)

# %%
final=final_df.copy()
test=final['result']
train=final.drop('result',axis=1)

# %%
from sklearn.model_selection import train_test_split
X_train,X_test,y_train,y_test=train_test_split(train,test,test_size=0.3,random_state=1)

# %%
from sklearn import metrics
from sklearn.compose import ColumnTransformer
from sklearn.preprocessing import OneHotEncoder
from sklearn.linear_model import LogisticRegression
from sklearn.ensemble import RandomForestClassifier
from sklearn.pipeline import Pipeline
from sklearn.ensemble import GradientBoostingClassifier

# %%
cf = ColumnTransformer([
    ('trf',OneHotEncoder(sparse_output=False,drop='first'),['batting_team','bowling_team','city'])
],remainder='passthrough')

# %%
final
# Out:
#                        batting_team         bowling_team       city  \
# 125     Royal Challengers Bangalore  Sunrisers Hyderabad  Hyderabad
# 126     Royal Challengers Bangalore  Sunrisers Hyderabad  Hyderabad
# 127     Royal Challengers Bangalore  Sunrisers Hyderabad  Hyderabad
# 128     Royal Challengers Bangalore  Sunrisers Hyderabad  Hyderabad
# 129     Royal Challengers Bangalore  Sunrisers Hyderabad  Hyderabad
# ...                             ...                  ...        ...
# 149572          Chennai Super Kings       Mumbai Indians  Hyderabad
# 149573          Chennai Super Kings       Mumbai Indians  Hyderabad
# 149574          Chennai Super Kings       Mumbai Indians  Hyderabad
# 149575          Chennai Super Kings       Mumbai Indians  Hyderabad
# 149576          Chennai Super Kings       Mumbai Indians  Hyderabad
#
#         balls_left  wickets_left  total_runs_x  current_runrate  req_runrate  \
# ...

# %%
pipe = Pipeline(steps=[
    ('step1',cf),
    ('step2',LogisticRegression(solver='liblinear'))
])

pipe.fit(X_train,y_train)
# Out:
# C:\Users\Asus\AppData\Local\Packages\PythonSoftwareFoundation.Python.3.12_qbz5n2kfra8p0\LocalCache\local-packages\Python312\site-packages\sklearn\compose\_column_transformer.py:1624: FutureWarning:
# The format of the columns of the 'remainder' transformer in ColumnTransformer.transformers_ will change in version 1.7 to match the format of the other transformers.
# At the moment the remainder columns are stored as indices (of type int). With the same ColumnTransformer configuration, in the future they will be stored as column names (of type str).
# To use the new behavior now and suppress this warning, use ColumnTransformer(force_int_remainder_cols=False).
#
#   warnings.warn(
# Pipeline(steps=[('step1',
#                  ColumnTransformer(remainder='passthrough',
#                                    transformers=[('trf',
#                                                   OneHotEncoder(drop='first',
# ...

# %%
y_pred = pipe.predict(X_test)
print(metrics.accuracy_score(y_test,y_pred))
# Out:
# 0.7882874561241455

# %%
pipe.predict_proba(X_test)[5]
# Out:
# array([0.11597267, 0.88402733])

# %%
import xgboost as xgb
X_encoded = pd.get_dummies(train, columns=['batting_team', 'bowling_team', 'city'])
# Split the dataset into training and testing sets
X_train, X_test, y_train, y_test = train_test_split(X_encoded, test, test_size=0.3, random_state=42)
# Initialize the XGBoost regressor
xgb_reg = xgb.XGBRegressor(objective='reg:squarederror', random_state=42)

# Train the regressor
xgb_reg.fit(X_train, y_train)
# Make predictions
y_pred = xgb_reg.predict(X_test)
# Evaluate the regressor
mse = metrics.r2_score(y_test, y_pred)
print(f"XGBoost Mean Squared Error: {mse:.2f}")
# Out:
# XGBoost Mean Squared Error: 0.95

# %%
import pickle
pickle.dump(pipe,open('pipe.pkl','wb'))
